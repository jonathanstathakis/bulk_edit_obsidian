# %%
import polars as pl
from dateutil.parser import parse
from pyomd import Note, Notes, metadata
from pathlib import Path

vault_path = "/Users/jonathan/001_obsidian_vault"

# %%
notes = Notes(Path(vault_path))
notes
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/testing-batch-editing-obsidian-8Wu4M26a-py3.12/lib/python3.12/site-packages/pyomd/metadata.py:356, in Frontmatter._parse_1(cls, note_content)
#     355 try:
# --> 356     fm = frontmatter.loads(note_content)
#     357 except Exception as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/testing-batch-editing-obsidian-8Wu4M26a-py3.12/lib/python3.12/site-packages/frontmatter/__init__.py:185, in loads(text, encoding, handler, **defaults)
#     184 handler = handler or detect_format(text, handlers)
# --> 185 metadata, content = parse(text, encoding, handler, **defaults)
#     186 return Post(content, handler, **metadata)
#
# ...
